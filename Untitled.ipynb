# %% [markdown]
# Data Visualization

# %%
# Libaries needed for visualisation.
# %matplotlib inline
import numpy as np
import pandas as pd
# The Matplotlib and Seaborn Python Libraries is used to create simple visualizations.
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set()

# %%
df = pd.read_csv("cleaned_data_v5.csv") # Loading files

# %%
df.head()# First 5 tuples in dataset
# Out:
#    Unnamed: 0             race  gender      age  days_in_hospital  \
# 0           0        Caucasian  Female   [0-10)                 1
# 1           1        Caucasian  Female  [10-20)                 3
# 2           2  AfricanAmerican  Female  [20-30)                 2
# 3           3        Caucasian    Male  [30-40)                 2
# 4           4        Caucasian    Male  [40-50)                 1
#
#    num_lab_procedures  num_not_lab_procedures  num_current_medications  \
# 0                  41                       0                        1
# 1                  59                       0                       18
# 2                  11                       5                       13
# 3                  44                       1                       16
# 4                  51                       0                        8
#
#    num_outpatient_appointments  num_previous_emergencies  ...     citoglipton  \
# 0                            0                         0  ...  not_prescribed
# 1                            0                         0  ...  not_prescribed
# 2                            2                         0  ...  not_prescribed
# 3                            0                         0  ...  not_prescribed
# 4                            0                         0  ...  not_prescribed
#
#             insulin glyburide-metformin glipizide-metformin  \
# 0    not_prescribed      not_prescribed      not_prescribed
# 1  dosage_increased      not_prescribed      not_prescribed
# 2    not_prescribed      not_prescribed      not_prescribed
# 3  dosage_increased      not_prescribed      not_prescribed
# 4  no_change_dosage      not_prescribed      not_prescribed
#
#   glimepiride-pioglitazone metformin-rosiglitazone metformin-pioglitazone  \
# 0           not_prescribed          not_prescribed         not_prescribed
# 1           not_prescribed          not_prescribed         not_prescribed
# 2           not_prescribed          not_prescribed         not_prescribed
# 3           not_prescribed          not_prescribed         not_prescribed
# 4           not_prescribed          not_prescribed         not_prescribed
#
#   change_in_meds diabates_med_prescribed readmitted
# 0             No                      No         NO
# 1             Ch                     Yes        >30
# 2             No                     Yes         NO
# 3             Ch                     Yes         NO
# 4             Ch                     Yes         NO
#
# [5 rows x 38 columns]

# %%
df['gender'].value_counts() # Get a count of the unique values
# Out:
# Female    53575
# Male      45917
# Name: gender, dtype: int64

# %%
labels = ["Female", "Male"]
colors = ['blue','orange'] # colours 
fig, ax1 = plt.subplots(figsize =(10,7))
ax1.pie(df['gender'].value_counts()
        ,colors=colors, startangle=90, autopct='%1.1f%%')
plt.title("Diabetes Patients by Gender", fontsize= 24)
ax1.legend(labels, loc="upper right")
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df['race'].value_counts()
# Out:
# Caucasian          76099
# AfricanAmerican    19210
# Hispanic            2037
# Other               1505
# Asian                641
# Name: race, dtype: int64

# %%
sns.set(font_scale=1.4)
df['race'].value_counts().plot(kind='bar', figsize=(10,6),rot=0)
plt.xlabel("Race/Ethnicity", labelpad=14)
plt.ylabel("Number of patients", labelpad=14)
plt.title("Diabetes Patients by Race/Ethinicity", y=1.06);

# %%
df['age'].value_counts()
# Out:
# [70-80)     25468
# [60-70)     21988
# [50-60)     16895
# [80-90)     16800
# [40-50)      9465
# [30-40)      3699
# [90-100)     2724
# [20-30)      1611
# [10-20)       682
# [0-10)        160
# Name: age, dtype: int64

# %%
df['age'].value_counts().plot(kind='barh', figsize=(8,6))
plt.xlabel("Number of Patients", labelpad=14)
plt.ylabel("Age",labelpad=14)
plt.title("Number of Patients with Diabetes by Age",y=1.02);

# %%
df['readmitted'].value_counts()
# Out:
# NO     53316
# >30    35007
# <30    11169
# Name: readmitted, dtype: int64

# %%
labels = ["Have not been readmitted", "Readmitted after 30 days or more", "Readmitted within 30 Days"]
colors = ['red','blue','green'] # colours 
fig, ax1 = plt.subplots(figsize =(17,7))
ax1.pie(df['readmitted'].value_counts()
        ,colors=colors, startangle=90, autopct='%1.1f%%')
plt.title("Patients Readmittance", fontsize= 24)
ax1.legend(labels, loc="upper right")
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df['days_in_hospital'].value_counts()
# Out:
# 3     17342
# 2     16841
# 1     13877
# 4     13605
# 5      9763
# 6      7366
# 7      5720
# 8      4297
# 9      2940
# 10     2291
# 11     1816
# 12     1427
# 13     1189
# 14     1018
# Name: days_in_hospital, dtype: int64

# %%
sns.set(font_scale=1.4)
df['days_in_hospital'].value_counts().plot(kind='bar', figsize=(7,6), rot=0)
plt.xlabel("Days in Hospital", labelpad=14)
plt.ylabel("Number of Patients",labelpad=14)
plt.title("Days spent in Hopsital");

# %%
df['change_in_meds'].value_counts()
# Out:
# No    53582
# Ch    45910
# Name: change_in_meds, dtype: int64

# %%
sns.set(font_scale=1.4)
df['change_in_meds'].value_counts().plot(kind='bar', figsize=(7,6), rot=0)
plt.xlabel("Changes", labelpad=14)
plt.ylabel("Number of Patients",labelpad=14)
plt.title("Change in Medication");

# %%
df['num_current_medications'].value_counts()
# Out:
# 13    5929
# 12    5866
# 11    5664
# 15    5662
# 14    5579
#       ...
# 70       2
# 75       2
# 74       1
# 79       1
# 81       1
# Name: num_current_medications, Length: 75, dtype: int64

# %%
df['num_current_medications'].value_counts().plot(kind ='bar', figsize=(28,6), rot=0)
plt.xlabel("Number of Medication", labelpad=14)
plt.ylabel("Number of Patients",labelpad=14)
plt.title("Number of Medication used by Patients");

# %%
df['diabates_med_prescribed'].value_counts()
# Out:
# Yes    76491
# No     23001
# Name: diabates_med_prescribed, dtype: int64

# %%
df['diabates_med_prescribed'].value_counts().plot(kind='pie', figsize=(7,6), rot=0)
plt.ylabel("Number of Patients",labelpad=14)
plt.title("Have patients have been prescribed Diabetes Medication?");

# %%
df['insulin'].value_counts()
# Out:
# not_prescribed      46495
# no_change_dosage    29902
# dosage_decreased    12039
# dosage_increased    11056
# Name: insulin, dtype: int64

# %%
df['insulin'].value_counts().plot(kind='bar', figsize=(10,6), rot=0)
plt.xlabel("Insulin", labelpad=14)
plt.ylabel("Number of Patients",labelpad=14)
plt.title("Insulin Prescriptions");

# %%
df['number_diagnoses'].value_counts()
# Out:
# 9     48694
# 5     10698
# 8     10440
# 7     10196
# 6     10005
# 4      5388
# 3      2767
# 2       983
# 1       214
# 16       40
# 13       16
# 10       16
# 11       11
# 12        9
# 15        8
# 14        7
# Name: number_diagnoses, dtype: int64

# %%
df['number_diagnoses'].value_counts().plot(kind='bar', figsize=(10,6), rot=0)
plt.xlabel("Number of Diagnoses", labelpad=14)
plt.ylabel("Number of Patients",labelpad=14)
plt.title("Number of Patient Diagnoses");
